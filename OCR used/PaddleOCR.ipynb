# %%
pip install paddleocr
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 27.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 32.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ------ --------------------------------- 7.3/46.2 MB 37.8 MB/s eta 0:00:02
#    ------------- -------------------------- 15.2/46.2 MB 36.8 MB/s eta 0:00:01
#    ------------------- -------------------- 22.8/46.2 MB 36.1 MB/s eta 0:00:01
#    -------------------------- ------------- 30.4/46.2 MB 35.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 34.1/46.2 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.1/46.2 MB 31.9 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Discussion
# - PaddleOCR wasn't used because it uses lower versions of tensorflow-intel and numpy. which could affect other functions in the program
